# %%
# 0 -4132
# 1 - 4684
# 2 - 4177
# 3 - 4351
# 4 - 4072
# 5 - 3795
# 6 - 4137
# 7 - 4401
# 8 - 4063
# 9 - 4188

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
columns=[i for i in range(784)]

# %% [markdown]
# # for zero images flattern to dataframe

# %%
df_0 = pd.DataFrame(columns = columns)
for i in range(0,4132):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\0\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_0.loc[len(df_0.index)] = flattered 
label_0 = ['0' for i in range(4132)]
df_0['Label'] =label_0
df_0.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %% [markdown]
# # for 1 flattern image

# %%
df_1 = pd.DataFrame(columns = columns)
for i in range(0,4684):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\1\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_1.loc[len(df_1.index)] = flattered 
label_1 = ['1' for i in range(4684)]
df_1['Label'] =label_1
df_1.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %% [markdown]
# # this  is for '2' images  flattern

# %%
df_2 = pd.DataFrame(columns = columns)
for i in range(0,4177):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\2\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_2.loc[len(df_2.index)] = flattered 
label_2 = ['2' for i in range(4177)]
df_2['Label'] =label_2
df_2.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %%
df_3 = pd.DataFrame(columns = columns)
for i in range(0,4351):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\3\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_3.loc[len(df_3.index)] = flattered 
label_3 = ['3' for i in range(4351)]
df_3['Label'] =label_3
df_3.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %%
df_4 = pd.DataFrame(columns = columns)
for i in range(0,4072):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\4\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_4.loc[len(df_4.index)] = flattered 
label_4 = ['4' for i in range(4072)]
df_4['Label'] =label_4
df_4.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %%
df_5 = pd.DataFrame(columns = columns)
for i in range(0,3795):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\5\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_5.loc[len(df_5.index)] = flattered 
label_5 = ['5' for i in range(3795)]
df_5['Label'] =label_5
df_5.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %%
df_6 = pd.DataFrame(columns = columns)
for i in range(0,4137):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\6\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_6.loc[len(df_6.index)] = flattered 
label_6 = ['6' for i in range(4137)]
df_6['Label'] =label_6
df_6.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %%
df_7 = pd.DataFrame(columns = columns)
for i in range(0,4401):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\7\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_7.loc[len(df_7.index)] = flattered 
label_7 = ['7' for i in range(4401)]
df_7['Label'] =label_7
df_7.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %%
df_8 = pd.DataFrame(columns = columns)
for i in range(0,4063):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\8\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_8.loc[len(df_8.index)] = flattered 
label_8 = ['8' for i in range(4063)]
df_8['Label'] =label_8
df_8.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %%
df_9 = pd.DataFrame(columns = columns)
for i in range(0,4188):
    digits = mpimg.imread(r'C:\Users\ramgari mukeshreddy\Downloads\mnist_data\9\img_{}.png'.format(i))
    slicing= digits[:,:,1]
    flattered =slicing.flatten()
    df_9.loc[len(df_9.index)] = flattered 
label_9 = ['9' for i in range(4188)]
df_9['Label'] =label_9
df_9.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 1  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 2  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 3  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
# 4  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922  0.003922
#
#         779       780       781       782       783  Label
# ...

# %%
df_total=pd.concat([df_0,df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9],ignore_index = True,sort = False)
df_total
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 3      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 4      0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# ...         ...       ...       ...       ...       ...       ...       ...
# 41995  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 41996  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 41997  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 41998  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 41999  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
# ...

# %%
df_total[:,:784]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RAMGAR~1\AppData\Local\Temp/ipykernel_8364/442142304.py in <module>
# ----> 1 df_total[:,:784]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ...

# %%
X=df_total.iloc[:,:784]
target=df_total.iloc[:,784]

# %% [markdown]
# # ML train and test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,target,test_size = 0.25,random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train,y_train)
# Out:
# C:\Users\ramgari mukeshreddy\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_test_pred = classifier.predict(X_test)

# %%
y_test_pred
# Out:
# array(['7', '4', '4', ..., '0', '3', '9'], dtype=object)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.9207619047619048

# %%
con_metrics = metrics.confusion_matrix(y_test,y_test_pred)
con_metrics
# Out:
# array([[1007,    0,    2,    1,    1,   12,    8,    2,   13,    0],
#        [   0, 1140,    1,    8,    2,    1,    2,    0,   12,    1],
#        [   5,   13,  956,   15,    9,    5,    8,   11,   16,    7],
#        [   1,    6,   24,  965,    1,   29,    3,    9,   18,   10],
#        [   5,    4,    9,    2,  914,    1,   11,    3,    6,   32],
#        [  12,    6,    8,   50,   11,  830,   19,    6,   30,   10],
#        [  10,    3,   14,    0,    7,   10,  982,    0,    8,    0],
#        [   3,    4,   18,    5,    7,    2,    2, 1011,    3,   30],
#        [   7,   24,   12,   28,    5,   22,    2,    5,  883,   18],
#        [   7,    4,    3,   16,   25,    5,    0,   33,    9,  980]],
#       dtype=int64)

# %%
classifier.predict(X_train.head(1))
# Out:
# array(['1'], dtype=object)

# %%
y_train.he(2)
# Out:
# 5837    1
# Name: Label, dtype: object

# %%
X_test.tail(1)
# Out:
#             0         1         2         3         4         5         6    \
# 38244  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
#             7         8         9    ...       774       775       776  \
# 38244  0.003922  0.003922  0.003922  ...  0.003922  0.003922  0.003922
#
#             777       778       779       780       781       782       783
# 38244  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
#
# [1 rows x 784 columns]

# %%
y_test.tail(1)
# Out:
# 38244    9
# Name: Label, dtype: object

# %%
classifier.predict(X_test.tail(1))
# Out:
# array(['9'], dtype=object)

# %%
y_test.iloc[1000]
# Out:
# '7'

# %%
X_test.iloc[1000]
# Out:
# 0      0.003922
# 1      0.003922
# 2      0.003922
# 3      0.003922
# 4      0.003922
#          ...
# 779    0.003922
# 780    0.003922
# 781    0.003922
# 782    0.003922
# 783    0.003922
# Name: 30929, Length: 784, dtype: float32

# %%
classifier.predict([X_test.iloc[1000]])
# Out:
# array(['7'], dtype=object)
